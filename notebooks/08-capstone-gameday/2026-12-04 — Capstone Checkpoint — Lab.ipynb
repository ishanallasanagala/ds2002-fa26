# %% [markdown]
# # DS2002 · Capstone Checkpoint
#
# **Lab — 2026-12-04 · Fall 2026**
#
# ---

# %% [markdown]
# ## Lab 13 — Capstone checkpoint, final week
#
# Last graded checkpoint. Presentations are Monday, so anything broken here will be broken in front of the room.
#
# Questions 1 through 4 should be answered and Q5 underway. Every answer needs a number, a chart, and its caveat.

# %% [markdown]
# ### Q1 — Kickoff surge
#
# **TODO:** the number, the window you used, and the chart. State the window explicitly.

# %%
# TODO

# %% [markdown]
# **Q1 answer:** _..._

# %% [markdown]
# ### Q2 — Item consolidation
#
# **TODO:** distinct SKUs before, canonical products after, your largest family, and a before-and-after comparison. Include the assertion showing unit totals did not change.

# %%
# TODO

# %% [markdown]
# **Q2 answer:** _..._

# %% [markdown]
# ### Q3 — Weather-driven demand
#
# **TODO:** the API join and the relationship. Required: row count before and after the join, whether the data is live or fallback, weather confirmed for all six game dates, and the number of days your correlation covers.

# %%
# TODO

# %% [markdown]
# **Q3 answer, with its caveat:** _..._

# %% [markdown]
# ### Q4 — Zone and distance
#
# **TODO:** the pattern, normalized by zone capacity rather than raw totals, with group sizes reported so a reader knows which numbers to trust.

# %%
# TODO

# %% [markdown]
# **Q4 answer:** _..._

# %% [markdown]
# ### Q5 — Signal or artifact
#
# **TODO:** at least one query against `inventory_levels`, plus the sell-through calculation. Identify anything that sold out — for those items your demand figure is a floor, not a measurement, and your answer has to say so.

# %%
# TODO

# %% [markdown]
# **Q5 answer — is the poncho surge real demand?** _..._

# %% [markdown]
# ### Self-check

# %%
ready = {
    'q1_multiple_and_window': 'TODO',
    'q2_canonical_products': None,
    'q3_join_rows_preserved': None,       # True/False
    'q3_game_dates_with_weather': None,   # should be 6
    'q4_normalized_not_raw': False,
    'q5_sellouts_identified': None,       # how many items sold out
    'charts_with_message_titles': None,
    'decision_log_current': False,
    'readme_committed': False,
    'notebook_runs_clean': False,
}

for label, value in ready.items():
    ok = not (value is None or value is False
              or (isinstance(value, str) and value.startswith('TODO')))
    print('PASS' if ok else 'FAIL', '-', label, '=', value)
missing = [k for k, v in ready.items()
           if v is None or v is False
           or (isinstance(v, str) and v.startswith('TODO'))]
print()
print('ready to present:', not missing)
if missing:
    print(f'{len(missing)} to fix before Monday -- start with: {missing[0]}')

# %% [markdown]
# ### Write-up
#
# **a)** Your recommendation on ponchos in one sentence, with a number in it.
#
# **b)** The weakest part of your analysis, and what you will say if someone asks about it on Monday. Having this answer ready is the difference between a confident response and a scramble.

# %% [markdown]
# _your answer here_
