# %% [markdown]
# # DS2002 · Game Day Pulse — Capstone Starter
#
# **Template — 2026-11-16 · Fall 2026**
#
# ---

# %% [markdown]
# ## Game Day Pulse — Capstone Starter Template
#
# Copy this notebook into your team's repo and build on it. Sections match the brief's deliverables and rubric. Delete these instructions when you're done.
#
# **Environment:** Kaggle or Colab. **Data:** in `data/`. **API:** Open-Meteo (no key).

# %% [markdown]
# ### 0. Setup

# %%
import pandas as pd, numpy as np, sqlite3, requests
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 50)
DATA = 'data'  # adjust for Kaggle/Colab upload path

# %% [markdown]
# ### 1. Extract — load all sources

# %%
orders = pd.read_csv(f'{DATA}/gameday_orders.csv')
vendors = pd.read_csv(f'{DATA}/vendor_locations.csv')
menu = pd.read_csv(f'{DATA}/menu_catalog.csv')
zones = pd.read_csv(f'{DATA}/zone_capacity.csv')
conn = sqlite3.connect(f'{DATA}/inventory_and_sales.db')
print(orders.shape, vendors.shape, menu.shape, zones.shape)
print(pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", conn))

# %% [markdown]
# ### 2. Explore — find the mess
#
# TODO: `.info()`, `.isnull().sum()`, `.duplicated().sum()`, value counts on category/vendor_id.

# %%
# TODO

# %% [markdown]
# ### 3. Transform — cleaning pipeline
#
# TODO: dedup; clean `unit_price` ($ -> float); `quantity` -> numeric, drop negatives; parse `timestamp`; normalize `vendor_id`, `category`; consolidate SKU/name fragments.

# %%
# TODO: build a clean_orders DataFrame

# %% [markdown]
# ### 4. Weather (API) — Open-Meteo
#
# TODO: pull weather for the game dates; join on date.

# %%
# TODO: cite base URL https://archive-api.open-meteo.com/v1/archive

# %% [markdown]
# ### 5. Load — write cleaned tables to SQLite

# %%
# TODO: clean_orders.to_sql('clean_orders', conn, ...)

# %% [markdown]
# ### 6. Analysis — Questions 1–5
#
# One section each; code + chart + written answer.

# %%
# Q1 kickoff surge

# %%
# Q2 item consolidation

# %%
# Q3 weather-driven demand

# %%
# Q4 zone & distance

# %%
# Q5 rain poncho signal vs artifact (query inventory_levels)

# %% [markdown]
# ### 7. Reflection
#
# Answer the 5 reflection questions from the brief (every member contributes).

# %% [markdown]
# _reflection here_
