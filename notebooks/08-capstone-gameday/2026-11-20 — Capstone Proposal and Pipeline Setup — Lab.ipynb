# %% [markdown]
# # DS2002 · Capstone Proposal and Pipeline Setup
#
# **Lab — 2026-11-20 · Fall 2026**
#
# ---

# %% [markdown]
# ## Lab 12 — Capstone proposal and pipeline setup
#
# One submission per team, week 1 of 4. Graded on evidence that the pipeline runs, not on the plan being ambitious.
#
# The point of a week-1 checkpoint is to make sure nobody is four weeks into a project that has not loaded its data yet. If something is not working, report the actual error.

# %% [markdown]
# ### 1 — Proposal
#
# **a)** Which of the five questions will your team emphasize, and why does it matter to the vendors?
#
# **b)** Your recommendation hypothesis — what do you *expect* to end up telling them? Writing this down now is useful precisely because the data may contradict it, and noticing that is a finding.
#
# **c)** What would have to be true in the data for your hypothesis to be wrong?

# %% [markdown]
# _proposal here_

# %% [markdown]
# ### 2 — All five sources loading
#
# **TODO:** paste the loader and its output. Every source, with row and column counts, including the SQLite database. Use the path-resolving pattern so it works for whoever opens this next.

# %%
# TODO

# %% [markdown]
# ### 3 — Join keys checked
#
# **TODO:** for each join you plan to make, show the distinct key counts on both sides, what is missing from either, and whether the right-hand key is unique.
#
# This is the section that predicts whether week 2 goes well.

# %%
# TODO

# %% [markdown]
# ### 4 — Cleaning started
#
# **TODO:** as functions, not loose cells. At minimum duplicates, prices to numeric, quantities with your stated decision, and timestamps parsed. Print row counts before and after.

# %%
# TODO

# %% [markdown]
# ### 5 — Decision log
#
# **TODO:** every decision so far with the number of rows it touched.

# %%
# TODO

# %% [markdown]
# ### 6 — One working weather call, cited
#
# **TODO:** the call with retries, the parsed frame, a `source` column, and a citation showing the endpoint, coordinates, date range, and when you pulled it.

# %%
# TODO

# %% [markdown]
# ### 7 — Self-check

# %%
setup = {
    'sources_loading': None,        # TODO: how many of 5
    'join_keys_checked': False,     # TODO
    'rows_after_cleaning': None,    # TODO: an integer
    'decisions_logged': None,       # TODO: how many entries
    'weather_api_rows': None,       # TODO: rows returned
    'repo_url': 'TODO',
    'notebook_owner_this_week': 'TODO',
    'notebook_runs_clean': False,   # TODO: True after Restart and Run All
}

for label, value in setup.items():
    ok = not (value is None or value is False
              or (isinstance(value, str) and value.startswith('TODO')))
    print('PASS' if ok else 'FAIL', '-', label, '=', value)
print()
print('week 1 complete:', all(
    not (v is None or v is False or (isinstance(v, str) and v.startswith('TODO')))
    for v in setup.values()))

# %% [markdown]
# ### 8 — Risk
#
# **a)** The most likely thing to go wrong over the next three weeks, specifically.
#
# **b)** What you are doing about it, who owns it, and by when. Remember next week is Thanksgiving and you effectively have one meeting.

# %% [markdown]
# _your answer here_
